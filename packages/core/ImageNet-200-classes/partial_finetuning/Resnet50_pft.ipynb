# %%
# https://drive.google.com/file/d/1b2GaBDI2iG206IcZTFUNl76ipGRjW3Tf/view?usp=sharing - google drive link
# Download the file using gdown
# !gdown --id 1b2GaBDI2iG206IcZTFUNl76ipGRjW3Tf
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1b2GaBDI2iG206IcZTFUNl76ipGRjW3Tf
# From (redirected): https://drive.google.com/uc?id=1b2GaBDI2iG206IcZTFUNl76ipGRjW3Tf&confirm=t&uuid=20734966-91a1-43d7-b062-c32f446cac10
# To: /content/mini_resized_3channel_8bit_depth_images.zip
# 100% 195M/195M [00:01<00:00, 128MB/s]

# %%
# !unzip mini_resized_3channel_8bit_depth_images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00011198.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00011198.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00045495.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00045495.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00014816.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00014816.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00011947.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00011947.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00000531.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00000531.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00023539.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00023539.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00040869.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00040869.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00007071.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00007071.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00020550.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00020550.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00018178.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00018178.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00006191.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00006191.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00010268.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00010268.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00016745.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00016745.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00043234.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00043234.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00026650.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00026650.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00046013.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00046013.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00037538.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00037538.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00003139.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00003139.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00023799.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00023799.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00002794.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00002794.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00001302.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00001302.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00033603.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00033603.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00046704.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00046704.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00034221.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00034221.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00026426.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00026426.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00012839.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00012839.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00034747.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00034747.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00032111.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00032111.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00025684.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00025684.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00019626.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00019626.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00017421.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00017421.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00031343.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00031343.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00016488.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00016488.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00045995.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00045995.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00038029.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00038029.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00031623.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00031623.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00004666.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00004666.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00005587.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00005587.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00021196.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00021196.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00022176.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00022176.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00017278.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00017278.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00019080.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00019080.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00034266.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00034266.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00021642.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00021642.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00002302.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00002302.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00033915.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00033915.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00019535.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00019535.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00006824.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00006824.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00044618.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00044618.png
#   inflating: mini_resized_3channel_8bit_depth_images/019/ILSVRC2012_val_00049498.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/019/._ILSVRC2012_val_00049498.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00032594.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00032594.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00047309.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00047309.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00048167.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00048167.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00042258.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00042258.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00008435.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00008435.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00044978.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00044978.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00035414.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00035414.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00025613.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00025613.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00002079.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00002079.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00047125.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00047125.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00034041.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00034041.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00005922.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00005922.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00009664.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00009664.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00020553.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00020553.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00048273.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00048273.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00010420.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00010420.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00016656.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00016656.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00018916.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00018916.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00012235.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00012235.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00036340.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00036340.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00039659.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00039659.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00029932.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00029932.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00049354.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00049354.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00018480.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00018480.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00032527.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00032527.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00028001.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00028001.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00023357.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00023357.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00008675.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00008675.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00031220.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00031220.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00009542.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00009542.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00000599.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00000599.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00049604.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00049604.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00011719.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00011719.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00035320.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00035320.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00028602.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00028602.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00019187.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00019187.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00019283.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00019283.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00030567.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00030567.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00017873.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00017873.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00011384.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00011384.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00013381.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00013381.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00005291.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00005291.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00020762.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00020762.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00027347.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00027347.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00027804.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00027804.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00042531.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00042531.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00037353.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00037353.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00027989.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00027989.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00025393.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00025393.png
#   inflating: mini_resized_3channel_8bit_depth_images/021/ILSVRC2012_val_00034275.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/021/._ILSVRC2012_val_00034275.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00000283.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00000283.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00035172.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00035172.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00032609.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00032609.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00034244.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00034244.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00000733.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00000733.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00021703.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00021703.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00000130.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00000130.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00041347.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00041347.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00016194.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00016194.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00014813.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00014813.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00016354.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00016354.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00001101.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00001101.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00007808.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00007808.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00032910.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00032910.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00024427.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00024427.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00002967.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00002967.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00010218.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00010218.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00043898.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00043898.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00002036.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00002036.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00023827.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00023827.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00008491.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00008491.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00015372.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00015372.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00037733.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00037733.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00001040.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00001040.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00012798.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00012798.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00026830.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00026830.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00009594.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00009594.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00031180.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00031180.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00027906.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00027906.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00001132.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00001132.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00010995.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00010995.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00004894.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00004894.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00033195.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00033195.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00005627.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00005627.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00017814.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00017814.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00040780.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00040780.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00049996.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00049996.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00044097.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00044097.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00009899.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00009899.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00013785.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00013785.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00008986.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00008986.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00014216.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00014216.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00039390.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00039390.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00004411.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00004411.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00024500.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00024500.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00023898.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00023898.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00003382.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00003382.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00020765.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00020765.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00016598.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00016598.png
#   inflating: mini_resized_3channel_8bit_depth_images/003/ILSVRC2012_val_00015898.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/003/._ILSVRC2012_val_00015898.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00023076.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00023076.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00002330.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00002330.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00038938.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00038938.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00017111.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00017111.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00022814.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00022814.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00013414.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00013414.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00047250.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00047250.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00003836.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00003836.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00049435.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00049435.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00042206.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00042206.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00003306.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00003306.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00047236.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00047236.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00024587.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00024587.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00006257.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00006257.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00014257.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00014257.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00036235.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00036235.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00004731.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00004731.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00043452.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00043452.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00045195.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00045195.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00036231.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00036231.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00018866.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00018866.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00013475.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00013475.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00017636.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00017636.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00025652.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00025652.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00047438.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00047438.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00033634.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00033634.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00034748.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00034748.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00004710.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00004710.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00044678.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00044678.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00023740.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00023740.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00023027.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00023027.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00037442.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00037442.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00009586.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00009586.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00041514.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00041514.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00003069.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00003069.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00024275.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00024275.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00033721.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00033721.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00006834.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00006834.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00033455.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00033455.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00031336.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00031336.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00022808.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00022808.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00017333.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00017333.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00048145.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00048145.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00007915.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00007915.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00035579.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00035579.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00032160.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00032160.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00001408.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00001408.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00028932.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00028932.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00006172.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00006172.png
#   inflating: mini_resized_3channel_8bit_depth_images/004/ILSVRC2012_val_00014589.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/004/._ILSVRC2012_val_00014589.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00004225.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00004225.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00023471.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00023471.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00027373.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00027373.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00045253.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00045253.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00008346.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00008346.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00002485.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00002485.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00044639.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00044639.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00009895.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00009895.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00043591.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00043591.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00035360.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00035360.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00010490.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00010490.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00025991.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00025991.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00039893.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00039893.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00045151.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00045151.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00049959.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00049959.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00009984.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00009984.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00044701.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00044701.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00015189.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00015189.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00048301.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00048301.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00011507.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00011507.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00040210.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00040210.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00033820.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00033820.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00030939.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00030939.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00027534.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00027534.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00019169.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00019169.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00007963.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00007963.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00009812.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00009812.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00043072.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00043072.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00000375.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00000375.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00022670.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00022670.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00012566.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00012566.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00006473.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00006473.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00038361.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00038361.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00043089.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00043089.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00014270.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00014270.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00003726.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00003726.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00041878.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00041878.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00021183.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00021183.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00012170.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00012170.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00011807.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00011807.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00046817.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00046817.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00026852.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00026852.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00022606.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00022606.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00031451.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00031451.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00035794.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00035794.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00016148.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00016148.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00049672.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00049672.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00007330.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00007330.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00010314.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00010314.png
#   inflating: mini_resized_3channel_8bit_depth_images/032/ILSVRC2012_val_00018947.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/032/._ILSVRC2012_val_00018947.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00045085.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00045085.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00024691.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00024691.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00017104.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00017104.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00049326.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00049326.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00015303.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00015303.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00000524.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00000524.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00012326.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00012326.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00018596.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00018596.png
#   inflating: mini_resized_3channel_8bit_depth_images/035/ILSVRC2012_val_00020593.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/035/._ILSVRC2012_val_00020593.png
# ...
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00007996.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00007996.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00038353.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00038353.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00038352.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00038352.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00037129.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00037129.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00019995.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00019995.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00026998.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00026998.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00018282.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00018282.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00033748.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00033748.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00035477.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00035477.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00004331.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00004331.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00043734.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00043734.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00035271.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00035271.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00034180.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00034180.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00026753.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00026753.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00023579.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00023579.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00030063.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00030063.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00006076.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00006076.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00009797.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00009797.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00024006.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00024006.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00020672.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00020672.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00012561.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00012561.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00004459.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00004459.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00031804.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00031804.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00029051.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00029051.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00033237.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00033237.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00020277.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00020277.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00041995.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00041995.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00026891.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00026891.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00047064.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00047064.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00026699.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00026699.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00027430.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00027430.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00011814.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00011814.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00014563.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00014563.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00030947.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00030947.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00021687.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00021687.png
#   inflating: mini_resized_3channel_8bit_depth_images/171/ILSVRC2012_val_00017335.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/171/._ILSVRC2012_val_00017335.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00042648.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00042648.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00006787.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00006787.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00017463.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00017463.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00044398.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00044398.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00044373.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00044373.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00024874.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00024874.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00003944.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00003944.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00012468.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00012468.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00035160.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00035160.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00028911.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00028911.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00046953.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00046953.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00023674.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00023674.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00047974.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00047974.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00040604.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00040604.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00009833.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00009833.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00017775.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00017775.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00014287.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00014287.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00000557.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00000557.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00008651.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00008651.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00043731.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00043731.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00029663.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00029663.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00034395.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00034395.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00043121.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00043121.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00009404.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00009404.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00002034.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00002034.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00042982.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00042982.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00027673.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00027673.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00042347.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00042347.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00035482.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00035482.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00034563.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00034563.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00027735.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00027735.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00025484.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00025484.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00016648.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00016648.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00033397.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00033397.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00013735.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00013735.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00031964.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00031964.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00007226.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00007226.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00041893.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00041893.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00048478.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00048478.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00005866.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00005866.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00037988.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00037988.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00047315.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00047315.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00049106.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00049106.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00033657.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00033657.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00042482.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00042482.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00045110.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00045110.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00018559.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00018559.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00020400.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00020400.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00035803.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00035803.png
#   inflating: mini_resized_3channel_8bit_depth_images/185/ILSVRC2012_val_00035751.png
#   inflating: __MACOSX/mini_resized_3channel_8bit_depth_images/185/._ILSVRC2012_val_00035751.png

# %%
# !pip install torchvision tqdm
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torchvision)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# import torch
# from torchvision import datasets, transforms
# from torch.utils.data import DataLoader
# import numpy as np
# from tqdm import tqdm

# # Assuming your dataset is in the 'mini_resized_3channel_8bit_depth_images' directory
# data_dir = 'mini_resized_3channel_8bit_depth_images'

# # Create a transform without normalization
# transform_no_norm = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor()
# ])

# # Create a dataset and DataLoader
# full_dataset_no_norm = datasets.ImageFolder(root=data_dir, transform=transform_no_norm)
# loader_no_norm = DataLoader(full_dataset_no_norm, batch_size=32, shuffle=False, num_workers=4)

# # Calculate mean and std
# mean = 0.0
# std = 0.0
# nb_samples = 0.0

# for images, _ in tqdm(loader_no_norm, desc="Calculating mean and std"):
#     batch_samples = images.size(0)
#     images = images.view(batch_samples, images.size(1), -1)
#     mean += images.mean(2).sum(0)
#     std += images.std(2).sum(0)
#     nb_samples += batch_samples

# mean /= nb_samples
# std /= nb_samples

# print(f"Calculated mean: {mean}")
# print(f"Calculated std: {std}")
# Calculating mean and std: 100%|██████████| 313/313 [00:26<00:00, 11.65it/s]Calculated mean: tensor([0.3762, 0.3762, 0.3762])
# Calculated std: tensor([0.2760, 0.2760, 0.2760])

# %%
import torch
from torchvision import datasets, transforms, models
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torch.optim import Adam
import random
from tqdm import tqdm
import matplotlib.pyplot as plt

# 1. Reproducibility
SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)

# 2. Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. Transforms
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406],  # imagenet mean and std
    #                      std=[0.229, 0.224, 0.225])
    transforms.Normalize(mean=[0.3762, 0.3762, 0.3762],  # our dataset mean/std
                         std=[0.2760, 0.2760, 0.2760])
])


val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.3762, 0.3762, 0.3762],
                         std=[0.2760, 0.2760, 0.2760])
])

# %%
# 4. Load dataset and split indices
data_dir = 'mini_resized_3channel_8bit_depth_images'
full_dataset = datasets.ImageFolder(root=data_dir)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

# Get shuffled indices for reproducibility
indices = list(range(len(full_dataset)))
random.shuffle(indices)
train_indices = indices[:train_size]
val_indices = indices[train_size:]

#5. Split using Subset
train_dataset = torch.utils.data.Subset(full_dataset, train_indices)
val_dataset = torch.utils.data.Subset(full_dataset, val_indices)

# 6. Assign transforms afterwards
train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# Print dimensions of a few images from the training set
print("\nTraining set image dimensions:")
for images, labels in train_loader:
    for i, img in enumerate(images[:2]):  # Print dimensions of the first 2 images
        print(f"Image {i + 1} dimensions: {img.shape}")
    break  # Exit after processing the first batch

# Print dimensions of a few images from the validation set
print("\nValidation set image dimensions:")
for images, labels in val_loader:
    for i, img in enumerate(images[:2]):  # Print dimensions of the first 2 images
        print(f"Image {i + 1} dimensions: {img.shape}")
    break  # Exit after processing the first batch

    # Get size of train and validation sets
train_size = len(train_dataset)
val_size = len(val_dataset)

print(f"Training set size: {train_size:,}")
print(f"Validation set size: {val_size:,}")
# Out:
# Training set image dimensions:
# Image 1 dimensions: torch.Size([3, 224, 224])
# Image 2 dimensions: torch.Size([3, 224, 224])
#
# Validation set image dimensions:
# Image 1 dimensions: torch.Size([3, 224, 224])
# Image 2 dimensions: torch.Size([3, 224, 224])
# Training set size: 8,000
# Validation set size: 2,000

# %%
# 7. Load and modify pretrained ResNet50
import torch.nn as nn
from torchvision import models

# Load a pretrained ResNet50 model
weights = models.ResNet50_Weights.DEFAULT
model = models.resnet50(weights=weights)

# model = models.resnet50(pretrained=True)

# Freeze all layers initially
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the last few layers 
for param in model.fc.parameters():
    param.requires_grad = True

# Unfreeze the last convolutional block (layer4 in ResNet50)
for param in model.layer4.parameters():
    param.requires_grad = True

# Replace the classifier (fully connected layer) to match the number of classes
# The input features for the classifier of ResNet50 is 2048
num_ftrs = model.fc.in_features

# Add a dropout layer before the final classification layer
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1024),  # Add intermediate layer
    nn.BatchNorm1d(1024),       
    nn.ReLU(),
    nn.Dropout(p=0.7), 
    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Dropout(p=0.6),
    nn.Linear(512, 200)         # Final classifier for 200 classes
)


model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.7, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.6, inplace=False)
#     (7): Linear(in_features=512, out_features=200, bias=True)
#   )
# )

# %%
# Print the number of trainable and frozen parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen_params = total_params - trainable_params

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Frozen parameters: {frozen_params:,}")
# Out:
# Total parameters: 26,235,656
# Trainable parameters: 17,692,360
# Frozen parameters: 8,543,296

# %%
# 8. Optimizer and Loss
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau

optimizer = Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-5,
    weight_decay=1e-4  # L2 regularization
)
criterion = nn.CrossEntropyLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='max', patience=5, factor=0.5)

# %%
num_epochs = 80

train_loss_list = []
val_loss_list = []
train_top1_list = []
train_top5_list = []
val_top1_list = []
val_top5_list = []

best_val_accuracy = 0.0

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    correct_top1 = 0
    correct_top5 = 0
    total_train = 0

    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * images.size(0)

        # Top-1
        _, predicted = torch.max(outputs.data, 1)
        correct_top1 += (predicted == labels).sum().item()

        # Top-5
        top5_preds = torch.topk(outputs, 5, dim=1).indices
        correct_top5 += sum([labels[i] in top5_preds[i] for i in range(labels.size(0))])

        total_train += labels.size(0)

    train_top1_acc = correct_top1 / total_train * 100
    train_top5_acc = correct_top5 / total_train * 100
    avg_train_loss = train_loss / total_train

    train_loss_list.append(avg_train_loss)
    train_top1_list.append(train_top1_acc)
    train_top5_list.append(train_top5_acc)

    # Validation
    model.eval()
    val_loss = 0.0
    correct_top1 = 0
    correct_top5 = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in tqdm(val_loader, desc="Validation", leave=False):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * images.size(0)

            # Top-1
            _, predicted = torch.max(outputs.data, 1)
            correct_top1 += (predicted == labels).sum().item()

            # Top-5
            top5_preds = torch.topk(outputs, 5, dim=1).indices
            correct_top5 += sum([labels[i] in top5_preds[i] for i in range(labels.size(0))])

            total_val += labels.size(0)

    val_top1_acc = correct_top1 / total_val * 100
    val_top5_acc = correct_top5 / total_val * 100
    avg_val_loss = val_loss / total_val

    val_loss_list.append(avg_val_loss)
    val_top1_list.append(val_top1_acc)
    val_top5_list.append(val_top5_acc)

    # Scheduler step
    scheduler.step(val_top1_acc)

    print(f"Epoch {epoch + 1}")
    print(f"Top-1 Train Accuracy: {train_top1_acc:.2f}% --- Train Loss: {avg_train_loss:.4f}  |  Top-5 Train Accuracy: {train_top5_acc:.2f}%")
    print(f"Top-1 Val Accuracy:   {val_top1_acc:.2f}% --- Val Loss:   {avg_val_loss:.4f}  |  Top-5 Val Accuracy:   {val_top5_acc:.2f}%\n")

    # Save best model
    if val_top1_acc > best_val_accuracy:
        best_val_accuracy = val_top1_acc
        torch.save(model.state_dict(), 'best_model.pth')

print("Training Complete!")
# Out:
# Epoch 1
# Top-1 Train Accuracy: 0.61% --- Train Loss: 5.3905  |  Top-5 Train Accuracy: 2.80%
# Top-1 Val Accuracy:   0.85% --- Val Loss:   5.2816  |  Top-5 Val Accuracy:   4.25%
# Epoch 2
# Top-1 Train Accuracy: 0.69% --- Train Loss: 5.3413  |  Top-5 Train Accuracy: 3.65%
# Top-1 Val Accuracy:   2.10% --- Val Loss:   5.2535  |  Top-5 Val Accuracy:   6.30%
# Epoch 3
# Top-1 Train Accuracy: 0.80% --- Train Loss: 5.3078  |  Top-5 Train Accuracy: 4.04%
# Top-1 Val Accuracy:   3.50% --- Val Loss:   5.2278  |  Top-5 Val Accuracy:   9.45%
# Epoch 4
# Top-1 Train Accuracy: 1.09% --- Train Loss: 5.2670  |  Top-5 Train Accuracy: 4.95%
# Top-1 Val Accuracy:   5.35% --- Val Loss:   5.1997  |  Top-5 Val Accuracy:   12.65%
# Epoch 5
# Top-1 Train Accuracy: 1.70% --- Train Loss: 5.2242  |  Top-5 Train Accuracy: 5.78%
# Top-1 Val Accuracy:   7.20% --- Val Loss:   5.1670  |  Top-5 Val Accuracy:   18.75%
# Epoch 6
# Top-1 Train Accuracy: 1.80% --- Train Loss: 5.1935  |  Top-5 Train Accuracy: 7.06%
# Top-1 Val Accuracy:   9.40% --- Val Loss:   5.1312  |  Top-5 Val Accuracy:   23.50%
# Epoch 7
# Top-1 Train Accuracy: 2.73% --- Train Loss: 5.1368  |  Top-5 Train Accuracy: 9.71%
# Top-1 Val Accuracy:   11.40% --- Val Loss:   5.0792  |  Top-5 Val Accuracy:   28.80%
# Epoch 8
# Top-1 Train Accuracy: 3.08% --- Train Loss: 5.0924  |  Top-5 Train Accuracy: 10.61%
# Top-1 Val Accuracy:   13.20% --- Val Loss:   5.0288  |  Top-5 Val Accuracy:   31.65%
# Epoch 9
# Top-1 Train Accuracy: 3.57% --- Train Loss: 5.0444  |  Top-5 Train Accuracy: 12.03%
# Top-1 Val Accuracy:   14.30% --- Val Loss:   4.9676  |  Top-5 Val Accuracy:   33.95%
# Epoch 10
# Top-1 Train Accuracy: 5.05% --- Train Loss: 4.9697  |  Top-5 Train Accuracy: 15.28%
# Top-1 Val Accuracy:   15.45% --- Val Loss:   4.8991  |  Top-5 Val Accuracy:   36.40%
# Epoch 11
# Top-1 Train Accuracy: 5.71% --- Train Loss: 4.9002  |  Top-5 Train Accuracy: 18.40%
# Top-1 Val Accuracy:   16.60% --- Val Loss:   4.8186  |  Top-5 Val Accuracy:   38.25%
# Epoch 12
# Top-1 Train Accuracy: 6.93% --- Train Loss: 4.8200  |  Top-5 Train Accuracy: 20.26%
# Top-1 Val Accuracy:   16.85% --- Val Loss:   4.7363  |  Top-5 Val Accuracy:   39.05%
# Epoch 13
# Top-1 Train Accuracy: 7.88% --- Train Loss: 4.7561  |  Top-5 Train Accuracy: 21.44%
# Top-1 Val Accuracy:   17.70% --- Val Loss:   4.6312  |  Top-5 Val Accuracy:   39.70%
# Epoch 14
# Top-1 Train Accuracy: 9.19% --- Train Loss: 4.6678  |  Top-5 Train Accuracy: 24.76%
# Top-1 Val Accuracy:   18.20% --- Val Loss:   4.5388  |  Top-5 Val Accuracy:   41.25%
# Epoch 15
# Top-1 Train Accuracy: 10.01% --- Train Loss: 4.5843  |  Top-5 Train Accuracy: 27.20%
# Top-1 Val Accuracy:   19.10% --- Val Loss:   4.4519  |  Top-5 Val Accuracy:   41.95%
# Epoch 16
# Top-1 Train Accuracy: 10.76% --- Train Loss: 4.4970  |  Top-5 Train Accuracy: 28.84%
# Top-1 Val Accuracy:   19.95% --- Val Loss:   4.3484  |  Top-5 Val Accuracy:   43.90%
# Epoch 17
# Top-1 Train Accuracy: 12.21% --- Train Loss: 4.4092  |  Top-5 Train Accuracy: 31.50%
# Top-1 Val Accuracy:   20.20% --- Val Loss:   4.2403  |  Top-5 Val Accuracy:   45.05%
# Epoch 18
# Top-1 Train Accuracy: 13.79% --- Train Loss: 4.3205  |  Top-5 Train Accuracy: 33.46%
# Top-1 Val Accuracy:   21.90% --- Val Loss:   4.1576  |  Top-5 Val Accuracy:   46.65%
# Epoch 19
# Top-1 Train Accuracy: 14.46% --- Train Loss: 4.2225  |  Top-5 Train Accuracy: 36.76%
# Top-1 Val Accuracy:   22.05% --- Val Loss:   4.0612  |  Top-5 Val Accuracy:   47.50%
# Epoch 20
# Top-1 Train Accuracy: 16.06% --- Train Loss: 4.1359  |  Top-5 Train Accuracy: 38.25%
# Top-1 Val Accuracy:   23.15% --- Val Loss:   3.9763  |  Top-5 Val Accuracy:   49.20%
# Epoch 21
# Top-1 Train Accuracy: 17.30% --- Train Loss: 4.0578  |  Top-5 Train Accuracy: 39.71%
# Top-1 Val Accuracy:   23.80% --- Val Loss:   3.9007  |  Top-5 Val Accuracy:   50.35%
# Epoch 22
# Top-1 Train Accuracy: 18.59% --- Train Loss: 3.9540  |  Top-5 Train Accuracy: 42.05%
# Top-1 Val Accuracy:   25.40% --- Val Loss:   3.8082  |  Top-5 Val Accuracy:   51.35%
# Epoch 23
# Top-1 Train Accuracy: 19.89% --- Train Loss: 3.8658  |  Top-5 Train Accuracy: 44.38%
# Top-1 Val Accuracy:   25.55% --- Val Loss:   3.7120  |  Top-5 Val Accuracy:   52.05%
# Epoch 24
# Top-1 Train Accuracy: 20.66% --- Train Loss: 3.7927  |  Top-5 Train Accuracy: 45.42%
# Top-1 Val Accuracy:   25.85% --- Val Loss:   3.6315  |  Top-5 Val Accuracy:   53.25%
# Epoch 25
# Top-1 Train Accuracy: 22.82% --- Train Loss: 3.7111  |  Top-5 Train Accuracy: 46.89%
# Top-1 Val Accuracy:   27.05% --- Val Loss:   3.5359  |  Top-5 Val Accuracy:   54.65%
# Epoch 26
# Top-1 Train Accuracy: 23.86% --- Train Loss: 3.6213  |  Top-5 Train Accuracy: 49.29%
# Top-1 Val Accuracy:   27.90% --- Val Loss:   3.4770  |  Top-5 Val Accuracy:   55.60%
# Epoch 27
# Top-1 Train Accuracy: 25.24% --- Train Loss: 3.5298  |  Top-5 Train Accuracy: 51.19%
# Top-1 Val Accuracy:   28.40% --- Val Loss:   3.4265  |  Top-5 Val Accuracy:   56.75%
# Epoch 28
# Top-1 Train Accuracy: 27.30% --- Train Loss: 3.4418  |  Top-5 Train Accuracy: 53.09%
# Top-1 Val Accuracy:   29.65% --- Val Loss:   3.3562  |  Top-5 Val Accuracy:   58.50%
# Epoch 29
# Top-1 Train Accuracy: 28.41% --- Train Loss: 3.3409  |  Top-5 Train Accuracy: 54.84%
# Top-1 Val Accuracy:   30.40% --- Val Loss:   3.2836  |  Top-5 Val Accuracy:   59.10%
# Epoch 30
# Top-1 Train Accuracy: 29.18% --- Train Loss: 3.2746  |  Top-5 Train Accuracy: 56.12%
# Top-1 Val Accuracy:   31.35% --- Val Loss:   3.2257  |  Top-5 Val Accuracy:   60.15%
# Epoch 31
# Top-1 Train Accuracy: 31.84% --- Train Loss: 3.1874  |  Top-5 Train Accuracy: 58.49%
# Top-1 Val Accuracy:   32.60% --- Val Loss:   3.1535  |  Top-5 Val Accuracy:   61.30%
# Epoch 32
# Top-1 Train Accuracy: 31.99% --- Train Loss: 3.1140  |  Top-5 Train Accuracy: 59.98%
# Top-1 Val Accuracy:   32.65% --- Val Loss:   3.1159  |  Top-5 Val Accuracy:   61.55%
# Epoch 33
# Top-1 Train Accuracy: 33.79% --- Train Loss: 3.0283  |  Top-5 Train Accuracy: 61.16%
# Top-1 Val Accuracy:   33.55% --- Val Loss:   3.0572  |  Top-5 Val Accuracy:   62.40%
# Epoch 34
# Top-1 Train Accuracy: 35.94% --- Train Loss: 2.9527  |  Top-5 Train Accuracy: 63.40%
# Top-1 Val Accuracy:   34.40% --- Val Loss:   2.9925  |  Top-5 Val Accuracy:   63.85%
# Epoch 35
# Top-1 Train Accuracy: 36.30% --- Train Loss: 2.8732  |  Top-5 Train Accuracy: 65.22%
# Top-1 Val Accuracy:   35.60% --- Val Loss:   2.9509  |  Top-5 Val Accuracy:   64.50%
# Epoch 36
# Top-1 Train Accuracy: 37.88% --- Train Loss: 2.7998  |  Top-5 Train Accuracy: 66.25%
# Top-1 Val Accuracy:   35.50% --- Val Loss:   2.9113  |  Top-5 Val Accuracy:   64.70%
# Epoch 37
# Top-1 Train Accuracy: 38.66% --- Train Loss: 2.7379  |  Top-5 Train Accuracy: 67.12%
# Top-1 Val Accuracy:   36.80% --- Val Loss:   2.8615  |  Top-5 Val Accuracy:   65.70%
# Epoch 38
# Top-1 Train Accuracy: 40.54% --- Train Loss: 2.6563  |  Top-5 Train Accuracy: 68.89%
# Top-1 Val Accuracy:   37.25% --- Val Loss:   2.8063  |  Top-5 Val Accuracy:   66.10%
# Epoch 39
# Top-1 Train Accuracy: 41.70% --- Train Loss: 2.5929  |  Top-5 Train Accuracy: 70.30%
# Top-1 Val Accuracy:   38.20% --- Val Loss:   2.7796  |  Top-5 Val Accuracy:   67.35%
# Epoch 40
# Top-1 Train Accuracy: 43.35% --- Train Loss: 2.5104  |  Top-5 Train Accuracy: 72.45%
# Top-1 Val Accuracy:   38.70% --- Val Loss:   2.7446  |  Top-5 Val Accuracy:   66.80%
# Epoch 41
# Top-1 Train Accuracy: 44.90% --- Train Loss: 2.4399  |  Top-5 Train Accuracy: 73.42%
# Top-1 Val Accuracy:   39.30% --- Val Loss:   2.7170  |  Top-5 Val Accuracy:   67.60%
# Epoch 42
# Top-1 Train Accuracy: 46.31% --- Train Loss: 2.3722  |  Top-5 Train Accuracy: 73.86%
# Top-1 Val Accuracy:   39.95% --- Val Loss:   2.6895  |  Top-5 Val Accuracy:   67.60%
# Epoch 43
# Top-1 Train Accuracy: 47.81% --- Train Loss: 2.3105  |  Top-5 Train Accuracy: 75.65%
# Top-1 Val Accuracy:   40.90% --- Val Loss:   2.6408  |  Top-5 Val Accuracy:   68.55%
# Epoch 44
# Top-1 Train Accuracy: 47.88% --- Train Loss: 2.2439  |  Top-5 Train Accuracy: 76.61%
# Top-1 Val Accuracy:   40.65% --- Val Loss:   2.6157  |  Top-5 Val Accuracy:   68.40%
# Epoch 45
# Top-1 Train Accuracy: 50.71% --- Train Loss: 2.1556  |  Top-5 Train Accuracy: 78.04%
# Top-1 Val Accuracy:   40.70% --- Val Loss:   2.5978  |  Top-5 Val Accuracy:   69.25%
# Epoch 46
# Top-1 Train Accuracy: 51.60% --- Train Loss: 2.0937  |  Top-5 Train Accuracy: 79.72%
# Top-1 Val Accuracy:   40.80% --- Val Loss:   2.5634  |  Top-5 Val Accuracy:   69.10%
# Epoch 47
# Top-1 Train Accuracy: 52.73% --- Train Loss: 2.0388  |  Top-5 Train Accuracy: 80.12%
# Top-1 Val Accuracy:   41.55% --- Val Loss:   2.5351  |  Top-5 Val Accuracy:   69.70%
# Epoch 48
# Top-1 Train Accuracy: 54.16% --- Train Loss: 1.9803  |  Top-5 Train Accuracy: 81.29%
# Top-1 Val Accuracy:   41.45% --- Val Loss:   2.5320  |  Top-5 Val Accuracy:   69.80%
# Epoch 49
# Top-1 Train Accuracy: 55.23% --- Train Loss: 1.9106  |  Top-5 Train Accuracy: 82.15%
# Top-1 Val Accuracy:   41.90% --- Val Loss:   2.5203  |  Top-5 Val Accuracy:   69.90%
# Epoch 50
# Top-1 Train Accuracy: 56.94% --- Train Loss: 1.8519  |  Top-5 Train Accuracy: 82.78%
# Top-1 Val Accuracy:   42.35% --- Val Loss:   2.5081  |  Top-5 Val Accuracy:   70.25%
# Epoch 51
# Top-1 Train Accuracy: 58.99% --- Train Loss: 1.7822  |  Top-5 Train Accuracy: 83.88%
# Top-1 Val Accuracy:   42.85% --- Val Loss:   2.4767  |  Top-5 Val Accuracy:   70.25%
# Epoch 52
# Top-1 Train Accuracy: 59.13% --- Train Loss: 1.7460  |  Top-5 Train Accuracy: 85.26%
# Top-1 Val Accuracy:   42.80% --- Val Loss:   2.4598  |  Top-5 Val Accuracy:   71.00%
# Epoch 53
# Top-1 Train Accuracy: 60.70% --- Train Loss: 1.6929  |  Top-5 Train Accuracy: 85.62%
# Top-1 Val Accuracy:   42.45% --- Val Loss:   2.4614  |  Top-5 Val Accuracy:   69.95%
# Epoch 54
# Top-1 Train Accuracy: 62.14% --- Train Loss: 1.6249  |  Top-5 Train Accuracy: 86.65%
# Top-1 Val Accuracy:   44.00% --- Val Loss:   2.4499  |  Top-5 Val Accuracy:   71.00%
# Epoch 55
# Top-1 Train Accuracy: 62.12% --- Train Loss: 1.5940  |  Top-5 Train Accuracy: 87.17%
# Top-1 Val Accuracy:   43.20% --- Val Loss:   2.4319  |  Top-5 Val Accuracy:   70.40%
# Epoch 56
# Top-1 Train Accuracy: 64.09% --- Train Loss: 1.5263  |  Top-5 Train Accuracy: 88.22%
# Top-1 Val Accuracy:   43.30% --- Val Loss:   2.4328  |  Top-5 Val Accuracy:   71.10%
# Epoch 57
# Top-1 Train Accuracy: 64.58% --- Train Loss: 1.4864  |  Top-5 Train Accuracy: 88.79%
# Top-1 Val Accuracy:   44.35% --- Val Loss:   2.4183  |  Top-5 Val Accuracy:   71.05%
# Epoch 58
# Top-1 Train Accuracy: 66.12% --- Train Loss: 1.4316  |  Top-5 Train Accuracy: 89.51%
# Top-1 Val Accuracy:   44.75% --- Val Loss:   2.4008  |  Top-5 Val Accuracy:   71.15%
# Epoch 59
# Top-1 Train Accuracy: 67.39% --- Train Loss: 1.3824  |  Top-5 Train Accuracy: 89.92%
# Top-1 Val Accuracy:   44.25% --- Val Loss:   2.4101  |  Top-5 Val Accuracy:   71.20%
# Epoch 60
# Top-1 Train Accuracy: 68.85% --- Train Loss: 1.3246  |  Top-5 Train Accuracy: 90.70%
# Top-1 Val Accuracy:   44.30% --- Val Loss:   2.3929  |  Top-5 Val Accuracy:   71.15%
# Epoch 61
# Top-1 Train Accuracy: 70.17% --- Train Loss: 1.2578  |  Top-5 Train Accuracy: 91.60%
# Top-1 Val Accuracy:   44.25% --- Val Loss:   2.3937  |  Top-5 Val Accuracy:   71.90%
# Epoch 62
# Top-1 Train Accuracy: 70.19% --- Train Loss: 1.2437  |  Top-5 Train Accuracy: 92.22%
# Top-1 Val Accuracy:   44.80% --- Val Loss:   2.3802  |  Top-5 Val Accuracy:   71.95%
# Epoch 63
# Top-1 Train Accuracy: 71.78% --- Train Loss: 1.2077  |  Top-5 Train Accuracy: 92.22%
# Top-1 Val Accuracy:   44.10% --- Val Loss:   2.3729  |  Top-5 Val Accuracy:   71.40%
# Epoch 64
# Top-1 Train Accuracy: 72.58% --- Train Loss: 1.1595  |  Top-5 Train Accuracy: 92.97%
# Top-1 Val Accuracy:   44.55% --- Val Loss:   2.3751  |  Top-5 Val Accuracy:   71.15%
# Epoch 65
# Top-1 Train Accuracy: 73.31% --- Train Loss: 1.1154  |  Top-5 Train Accuracy: 92.95%
# Top-1 Val Accuracy:   44.35% --- Val Loss:   2.3704  |  Top-5 Val Accuracy:   71.50%
# Epoch 66
# Top-1 Train Accuracy: 74.30% --- Train Loss: 1.0737  |  Top-5 Train Accuracy: 93.99%
# Top-1 Val Accuracy:   44.60% --- Val Loss:   2.3885  |  Top-5 Val Accuracy:   71.25%
# Epoch 67
# Top-1 Train Accuracy: 75.28% --- Train Loss: 1.0322  |  Top-5 Train Accuracy: 93.83%
# Top-1 Val Accuracy:   44.60% --- Val Loss:   2.3744  |  Top-5 Val Accuracy:   72.10%
# Epoch 68
# Top-1 Train Accuracy: 76.40% --- Train Loss: 1.0014  |  Top-5 Train Accuracy: 94.56%
# Top-1 Val Accuracy:   45.25% --- Val Loss:   2.3557  |  Top-5 Val Accuracy:   71.85%
# Epoch 69
# Top-1 Train Accuracy: 77.61% --- Train Loss: 0.9607  |  Top-5 Train Accuracy: 95.17%
# Top-1 Val Accuracy:   45.10% --- Val Loss:   2.3702  |  Top-5 Val Accuracy:   71.35%
# Epoch 70
# Top-1 Train Accuracy: 78.46% --- Train Loss: 0.9159  |  Top-5 Train Accuracy: 95.50%
# Top-1 Val Accuracy:   45.40% --- Val Loss:   2.3601  |  Top-5 Val Accuracy:   72.50%
# Epoch 71
# Top-1 Train Accuracy: 78.66% --- Train Loss: 0.9054  |  Top-5 Train Accuracy: 95.28%
# Top-1 Val Accuracy:   44.50% --- Val Loss:   2.3829  |  Top-5 Val Accuracy:   71.25%
# Epoch 72
# Top-1 Train Accuracy: 80.76% --- Train Loss: 0.8557  |  Top-5 Train Accuracy: 96.30%
# Top-1 Val Accuracy:   45.25% --- Val Loss:   2.3916  |  Top-5 Val Accuracy:   71.65%
# Epoch 73
# Top-1 Train Accuracy: 80.89% --- Train Loss: 0.8122  |  Top-5 Train Accuracy: 96.55%
# Top-1 Val Accuracy:   44.55% --- Val Loss:   2.3980  |  Top-5 Val Accuracy:   70.90%
# Epoch 74
# Top-1 Train Accuracy: 81.31% --- Train Loss: 0.7909  |  Top-5 Train Accuracy: 96.61%
# Top-1 Val Accuracy:   45.20% --- Val Loss:   2.3889  |  Top-5 Val Accuracy:   71.30%
# Epoch 75
# Top-1 Train Accuracy: 82.59% --- Train Loss: 0.7573  |  Top-5 Train Accuracy: 96.61%
# Top-1 Val Accuracy:   45.80% --- Val Loss:   2.3872  |  Top-5 Val Accuracy:   71.45%
# Epoch 76
# Top-1 Train Accuracy: 83.28% --- Train Loss: 0.7272  |  Top-5 Train Accuracy: 97.10%
# Top-1 Val Accuracy:   45.60% --- Val Loss:   2.3911  |  Top-5 Val Accuracy:   71.20%
# Epoch 77
# Top-1 Train Accuracy: 83.36% --- Train Loss: 0.7079  |  Top-5 Train Accuracy: 97.10%
# Top-1 Val Accuracy:   45.40% --- Val Loss:   2.3856  |  Top-5 Val Accuracy:   71.25%
# Epoch 78
# Top-1 Train Accuracy: 85.00% --- Train Loss: 0.6713  |  Top-5 Train Accuracy: 97.39%
# Top-1 Val Accuracy:   46.30% --- Val Loss:   2.3813  |  Top-5 Val Accuracy:   71.95%
# Epoch 79
# Top-1 Train Accuracy: 85.20% --- Train Loss: 0.6472  |  Top-5 Train Accuracy: 97.66%
# Top-1 Val Accuracy:   45.40% --- Val Loss:   2.4387  |  Top-5 Val Accuracy:   70.95%
# Epoch 80
# Top-1 Train Accuracy: 86.31% --- Train Loss: 0.6173  |  Top-5 Train Accuracy: 97.85%
# Top-1 Val Accuracy:   45.35% --- Val Loss:   2.4091  |  Top-5 Val Accuracy:   70.60%
#
# Training Complete!

# %%
import matplotlib.pyplot as plt

epochs = range(1, num_epochs + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_top1_list, label='Train Top-1 Accuracy', color='blue')
plt.plot(epochs, train_top5_list, label='Train Top-5 Accuracy', color='red')
plt.plot(epochs, val_top1_list, label='Val Top-1 Accuracy', color='green')
plt.plot(epochs, val_top5_list, label='Val Top-5 Accuracy', color='lime')

plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Top-1 and Top-5 Accuracy (Train & Validation)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, num_epochs + 1)

plt.figure(figsize=(10, 6))
# plt.plot(epochs, train_top1_list, label='Train Top-1 Accuracy', color='blue')
plt.plot(epochs, train_top5_list, label='Train Top-5 Accuracy', color='orange')
# plt.plot(epochs, val_top1_list, label='Val Top-1 Accuracy', color='green')
plt.plot(epochs, val_top5_list, label='Val Top-5 Accuracy', color='red')

plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Top-1 and Top-5 Accuracy (Train & Validation)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
